# %%
#================================= Start of importing required packages and libraries =========================================#
from __future__ import print_function
# %matplotlib inline
import numpy as np
import torch
from experiment_federated import *
import random
#================================== End of importing required packages and libraries ==========================================#

# %%
#=============================== Defining global variables ========================#
DATASET_NAME = "MNIST"
MODEL_NAME = "CNNMNIST"
DD_TYPE = 'IID'
ALPHA = 1
NUM_PEERS = 50 # "number of peers: K" 
FRAC_PEERS = 1 #'the fraction of peers: C to bel selected in each round'
SEED = 7 #fixed seed
random.seed(SEED)
CRITERION = nn.CrossEntropyLoss()
GLOBAL_ROUNDS = 50 #"number of rounds of federated model training"
LOCAL_EPOCHS = 3 #"the number of local epochs: E for each peer"
TEST_BATCH_SIZE = 1000
LOCAL_BS = 64 #"local batch size: B for each peer"
LOCAL_LR =  0.01#local learning rate: lr for each peer
LOCAL_MOMENTUM = 0.9 #local momentum for each peer
NUM_CLASSES = 10 # number of classes in an experiment
LABELS_DICT = {'Zero':0,
               'One':1, 
               'Two':2, 
               'Three':3, 
               'Four':4,
               'Five':5, 
               'Six':6, 
               'Seven':7, 
               'Eight':8, 
               'Nine':9}

#select the device to work with cpu or gpu
if torch.cuda.is_available():
    DEVICE = "cuda"
    print('GPU is available:', torch.cuda.get_device_name(0))
else:
    DEVICE = "cpu"
    print('GPU is not available, CPU will be used')
DEVICE = torch.device(DEVICE)
SOURCE_CLASS = 7 # the source class
TARGET_CLASS = 1 # the target class 

CLASS_PER_PEER = 10
SAMPLES_PER_CLASS = 582
RATE_UNBALANCE = 1
# Out:
# GPU is available: NVIDIA GeForce RTX 2060

# %%
# Baseline|: FedAvg-no attacks (FL)
RULE = 'fedavg'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0, 0.1]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, resume = False)
# Out:
# --> Starting experiment...
# --> Loading of MNIST dataset
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data\MNIST\raw\train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 32728817.35it/s]
# Extracting ./data\MNIST\raw\train-images-idx3-ubyte.gz to ./data\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data\MNIST\raw\train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 28883093.42it/s]
# Extracting ./data\MNIST\raw\train-labels-idx1-ubyte.gz to ./data\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data\MNIST\raw\t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 11353421.67it/s]
# Extracting ./data\MNIST\raw\t10k-images-idx3-ubyte.gz to ./data\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data\MNIST\raw\t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 4515413.31it/s]
# Extracting ./data\MNIST\raw\t10k-labels-idx1-ubyte.gz to ./data\MNIST\raw
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peets instances
# Data set: MNIST
# Data distribution: IID
# Aggregation rule: fedavg
# Attack Type: label_flipping
# Attackers Ratio: 0 %
# Malicious Behavior Rate: 100 %
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/50 [00:00<?, ?it/s]
#  | Global training round : 1/50 |
#
#
# Average test loss: 1.2199, Test accuracy: 7588/10000 (75.88%)
#
# Class      - Accuracy
# Zero       - 94.4
# One        - 97.6
# Two        - 76.4
# Three      - 84.4
# Four       - 85.2
# Five       - 47.8
# Six        - 78.7
# Seven      - 89.4
# Eight      - 54.6
# Nine       - 44.3
#
#  | Global training round : 2/50 |
#
#
# Average test loss: 0.4018, Test accuracy: 8992/10000 (89.92%)
#
# Class      - Accuracy
# Zero       - 97.8
# One        - 97.7
# Two        - 90.0
# Three      - 87.4
# Four       - 94.6
# Five       - 86.1
# Six        - 95.1
# Seven      - 90.8
# Eight      - 80.3
# Nine       - 78.3
#
#  | Global training round : 3/50 |
#
#
# Average test loss: 0.2704, Test accuracy: 9274/10000 (92.74%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.4
# Two        - 91.7
# Three      - 91.7
# Four       - 96.2
# Five       - 89.9
# Six        - 96.0
# Seven      - 91.8
# Eight      - 86.3
# Nine       - 86.2
#
#  | Global training round : 4/50 |
#
#
# Average test loss: 0.2105, Test accuracy: 9395/10000 (93.95%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.7
# Two        - 92.7
# Three      - 92.6
# Four       - 96.7
# Five       - 94.1
# Six        - 96.2
# Seven      - 92.8
# Eight      - 88.1
# Nine       - 88.7
#
#  | Global training round : 5/50 |
#
#
# Average test loss: 0.1753, Test accuracy: 9492/10000 (94.92%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.6
# Two        - 94.0
# Three      - 93.8
# Four       - 96.6
# Five       - 95.7
# Six        - 96.8
# Seven      - 92.6
# Eight      - 91.0
# Nine       - 91.6
#
#  | Global training round : 6/50 |
#
#
# Average test loss: 0.1537, Test accuracy: 9556/10000 (95.56%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.9
# Two        - 94.8
# Three      - 94.5
# Four       - 97.0
# Five       - 96.4
# Six        - 97.3
# Seven      - 93.5
# Eight      - 91.3
# Nine       - 93.2
#
#  | Global training round : 7/50 |
#
#
# Average test loss: 0.1384, Test accuracy: 9596/10000 (95.96%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.8
# Two        - 95.6
# Three      - 95.0
# Four       - 97.0
# Five       - 96.7
# Six        - 97.7
# Seven      - 94.0
# Eight      - 92.2
# Nine       - 93.8
#
#  | Global training round : 8/50 |
#
#
# Average test loss: 0.1269, Test accuracy: 9614/10000 (96.14%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 96.0
# Three      - 95.2
# Four       - 97.1
# Five       - 97.1
# Six        - 97.4
# Seven      - 94.2
# Eight      - 92.6
# Nine       - 94.2
#
#  | Global training round : 9/50 |
#
#
# Average test loss: 0.1186, Test accuracy: 9653/10000 (96.53%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.0
# Two        - 96.1
# Three      - 95.7
# Four       - 97.3
# Five       - 98.1
# Six        - 97.8
# Seven      - 94.5
# Eight      - 93.5
# Nine       - 94.6
#
#  | Global training round : 10/50 |
#
#
# Average test loss: 0.1105, Test accuracy: 9671/10000 (96.71%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.0
# Two        - 96.3
# Three      - 96.4
# Four       - 97.4
# Five       - 98.2
# Six        - 97.7
# Seven      - 94.6
# Eight      - 94.0
# Nine       - 94.8
#
#  | Global training round : 11/50 |
#
#
# Average test loss: 0.1042, Test accuracy: 9686/10000 (96.86%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.1
# Two        - 96.6
# Three      - 96.6
# Four       - 97.4
# Five       - 98.1
# Six        - 97.6
# Seven      - 94.9
# Eight      - 94.1
# Nine       - 95.3
#
#  | Global training round : 12/50 |
#
#
# Average test loss: 0.0999, Test accuracy: 9699/10000 (96.99%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 96.6
# Three      - 96.7
# Four       - 97.3
# Five       - 98.3
# Six        - 97.7
# Seven      - 95.4
# Eight      - 94.5
# Nine       - 95.6
#
#  | Global training round : 13/50 |
#
#
# Average test loss: 0.0947, Test accuracy: 9715/10000 (97.15%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.2
# Two        - 96.7
# Three      - 97.0
# Four       - 97.6
# Five       - 98.4
# Six        - 97.8
# Seven      - 95.6
# Eight      - 94.6
# Nine       - 95.8
#
#  | Global training round : 14/50 |
#
#
# Average test loss: 0.0917, Test accuracy: 9724/10000 (97.24%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.2
# Two        - 96.9
# Three      - 97.0
# Four       - 97.5
# Five       - 98.5
# Six        - 97.9
# Seven      - 95.7
# Eight      - 94.9
# Nine       - 95.9
#
#  | Global training round : 15/50 |
#
#
# Average test loss: 0.0875, Test accuracy: 9731/10000 (97.31%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.1
# Two        - 96.8
# Three      - 96.8
# Four       - 97.9
# Five       - 98.4
# Six        - 98.1
# Seven      - 95.9
# Eight      - 95.3
# Nine       - 95.9
#
#  | Global training round : 16/50 |
#
#
# Average test loss: 0.0856, Test accuracy: 9741/10000 (97.41%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.1
# Two        - 96.9
# Three      - 97.0
# Four       - 97.9
# Five       - 98.5
# Six        - 98.1
# Seven      - 95.8
# Eight      - 95.9
# Nine       - 95.9
#
#  | Global training round : 17/50 |
#
#
# Average test loss: 0.0830, Test accuracy: 9744/10000 (97.44%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.1
# Two        - 96.8
# Three      - 97.0
# Four       - 97.9
# Five       - 98.5
# Six        - 98.1
# Seven      - 96.0
# Eight      - 95.9
# Nine       - 96.1
#
#  | Global training round : 18/50 |
#
#
# Average test loss: 0.0804, Test accuracy: 9760/10000 (97.60%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.0
# Two        - 97.0
# Three      - 97.2
# Four       - 98.0
# Five       - 98.8
# Six        - 98.1
# Seven      - 96.4
# Eight      - 96.3
# Nine       - 96.2
#
#  | Global training round : 19/50 |
#
#
# Average test loss: 0.0786, Test accuracy: 9760/10000 (97.60%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.3
# Two        - 97.0
# Three      - 97.3
# Four       - 98.1
# Five       - 98.5
# Six        - 98.1
# Seven      - 96.6
# Eight      - 95.8
# Nine       - 96.2
#
#  | Global training round : 20/50 |
#
#
# Average test loss: 0.0767, Test accuracy: 9764/10000 (97.64%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.0
# Two        - 97.3
# Three      - 97.2
# Four       - 98.1
# Five       - 98.8
# Six        - 98.2
# Seven      - 96.4
# Eight      - 96.2
# Nine       - 96.3
#
#  | Global training round : 21/50 |
#
#
# Average test loss: 0.0741, Test accuracy: 9778/10000 (97.78%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.1
# Two        - 97.3
# Three      - 97.3
# Four       - 98.3
# Five       - 99.0
# Six        - 98.2
# Seven      - 96.6
# Eight      - 96.7
# Nine       - 96.2
#
#  | Global training round : 22/50 |
#
#
# Average test loss: 0.0727, Test accuracy: 9775/10000 (97.75%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.1
# Two        - 97.3
# Three      - 97.5
# Four       - 98.2
# Five       - 99.0
# Six        - 98.0
# Seven      - 96.4
# Eight      - 96.5
# Nine       - 96.3
#
#  | Global training round : 23/50 |
#
#
# Average test loss: 0.0714, Test accuracy: 9780/10000 (97.80%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 97.5
# Three      - 97.5
# Four       - 98.3
# Five       - 98.9
# Six        - 98.0
# Seven      - 96.7
# Eight      - 96.4
# Nine       - 96.3
#
#  | Global training round : 24/50 |
#
#
# Average test loss: 0.0694, Test accuracy: 9775/10000 (97.75%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.1
# Two        - 97.5
# Three      - 97.5
# Four       - 98.1
# Five       - 98.9
# Six        - 98.0
# Seven      - 96.7
# Eight      - 96.3
# Nine       - 96.3
#
#  | Global training round : 25/50 |
#
#
# Average test loss: 0.0679, Test accuracy: 9789/10000 (97.89%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 97.9
# Three      - 97.4
# Four       - 98.2
# Five       - 98.9
# Six        - 98.3
# Seven      - 96.6
# Eight      - 96.7
# Nine       - 96.5
#
#  | Global training round : 26/50 |
#
#
# Average test loss: 0.0668, Test accuracy: 9794/10000 (97.94%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 98.0
# Three      - 97.6
# Four       - 98.1
# Five       - 98.9
# Six        - 98.1
# Seven      - 96.7
# Eight      - 97.1
# Nine       - 96.6
#
#  | Global training round : 27/50 |
#
#
# Average test loss: 0.0664, Test accuracy: 9792/10000 (97.92%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.2
# Two        - 98.4
# Three      - 97.7
# Four       - 98.3
# Five       - 98.9
# Six        - 98.2
# Seven      - 96.5
# Eight      - 96.3
# Nine       - 96.5
#
#  | Global training round : 28/50 |
#
#
# Average test loss: 0.0649, Test accuracy: 9803/10000 (98.03%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.4
# Two        - 98.3
# Three      - 97.7
# Four       - 98.3
# Five       - 99.0
# Six        - 98.2
# Seven      - 96.8
# Eight      - 96.7
# Nine       - 96.8
#
#  | Global training round : 29/50 |
#
#
# Average test loss: 0.0635, Test accuracy: 9804/10000 (98.04%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.4
# Two        - 98.2
# Three      - 97.7
# Four       - 97.9
# Five       - 99.0
# Six        - 98.2
# Seven      - 96.8
# Eight      - 97.0
# Nine       - 97.1
#
#  | Global training round : 30/50 |
#
#
# Average test loss: 0.0625, Test accuracy: 9804/10000 (98.04%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.3
# Two        - 98.3
# Three      - 97.7
# Four       - 98.3
# Five       - 99.0
# Six        - 98.2
# Seven      - 96.8
# Eight      - 96.5
# Nine       - 97.0
#
#  | Global training round : 31/50 |
#
#
# Average test loss: 0.0607, Test accuracy: 9807/10000 (98.07%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.4
# Two        - 98.2
# Three      - 97.7
# Four       - 98.2
# Five       - 99.0
# Six        - 98.2
# Seven      - 96.9
# Eight      - 96.8
# Nine       - 97.1
#
#  | Global training round : 32/50 |
#
#
# Average test loss: 0.0611, Test accuracy: 9811/10000 (98.11%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.4
# Two        - 98.3
# Three      - 97.9
# Four       - 98.4
# Five       - 99.0
# Six        - 98.3
# Seven      - 96.8
# Eight      - 96.7
# Nine       - 97.0
#
#  | Global training round : 33/50 |
#
#
# Average test loss: 0.0600, Test accuracy: 9811/10000 (98.11%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.4
# Two        - 98.3
# Three      - 97.8
# Four       - 98.4
# Five       - 99.0
# Six        - 98.2
# Seven      - 96.8
# Eight      - 96.9
# Nine       - 97.0
#
#  | Global training round : 34/50 |
#
#
# Average test loss: 0.0592, Test accuracy: 9813/10000 (98.13%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.5
# Two        - 98.3
# Three      - 97.7
# Four       - 98.5
# Five       - 99.0
# Six        - 98.3
# Seven      - 97.2
# Eight      - 96.7
# Nine       - 96.8
#
#  | Global training round : 35/50 |
#
#
# Average test loss: 0.0571, Test accuracy: 9815/10000 (98.15%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.2
# Two        - 98.4
# Three      - 97.7
# Four       - 98.2
# Five       - 99.0
# Six        - 98.2
# Seven      - 97.2
# Eight      - 97.1
# Nine       - 97.2
#
#  | Global training round : 36/50 |
#
#
# Average test loss: 0.0573, Test accuracy: 9815/10000 (98.15%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.3
# Two        - 98.2
# Three      - 97.9
# Four       - 98.5
# Five       - 99.0
# Six        - 98.2
# Seven      - 97.2
# Eight      - 96.8
# Nine       - 97.1
#
#  | Global training round : 37/50 |
#
#
# Average test loss: 0.0564, Test accuracy: 9819/10000 (98.19%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.3
# Two        - 98.4
# Three      - 98.0
# Four       - 98.2
# Five       - 98.9
# Six        - 98.4
# Seven      - 97.1
# Eight      - 97.1
# Nine       - 97.2
#
#  | Global training round : 38/50 |
#
#
# Average test loss: 0.0559, Test accuracy: 9822/10000 (98.22%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.4
# Two        - 98.4
# Three      - 98.1
# Four       - 98.2
# Five       - 98.9
# Six        - 98.3
# Seven      - 97.4
# Eight      - 97.0
# Nine       - 97.1
#
#  | Global training round : 39/50 |
#
#
# Average test loss: 0.0552, Test accuracy: 9825/10000 (98.25%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.4
# Two        - 98.3
# Three      - 98.0
# Four       - 98.4
# Five       - 98.9
# Six        - 98.3
# Seven      - 97.4
# Eight      - 97.2
# Nine       - 97.2
#
#  | Global training round : 40/50 |
#
#
# Average test loss: 0.0551, Test accuracy: 9825/10000 (98.25%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.3
# Two        - 98.5
# Three      - 97.9
# Four       - 98.6
# Five       - 98.9
# Six        - 98.3
# Seven      - 97.2
# Eight      - 97.1
# Nine       - 97.2
#
#  | Global training round : 41/50 |
#
#
# Average test loss: 0.0548, Test accuracy: 9824/10000 (98.24%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.3
# Two        - 98.4
# Three      - 97.9
# Four       - 98.4
# Five       - 98.9
# Six        - 98.4
# Seven      - 97.2
# Eight      - 97.2
# Nine       - 97.2
#
#  | Global training round : 42/50 |
#
#
# Average test loss: 0.0540, Test accuracy: 9825/10000 (98.25%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.4
# Two        - 98.4
# Three      - 97.9
# Four       - 98.5
# Five       - 98.9
# Six        - 98.4
# Seven      - 97.1
# Eight      - 97.3
# Nine       - 97.1
#
#  | Global training round : 43/50 |
#
#
# Average test loss: 0.0529, Test accuracy: 9827/10000 (98.27%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.3
# Two        - 98.4
# Three      - 98.2
# Four       - 98.2
# Five       - 98.8
# Six        - 98.4
# Seven      - 97.3
# Eight      - 97.3
# Nine       - 97.2
#
#  | Global training round : 44/50 |
#
#
# Average test loss: 0.0528, Test accuracy: 9834/10000 (98.34%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.4
# Two        - 98.8
# Three      - 98.1
# Four       - 98.2
# Five       - 98.8
# Six        - 98.6
# Seven      - 97.4
# Eight      - 97.3
# Nine       - 97.2
#
#  | Global training round : 45/50 |
#
#
# Average test loss: 0.0528, Test accuracy: 9833/10000 (98.33%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.5
# Three      - 97.9
# Four       - 98.6
# Five       - 98.8
# Six        - 98.5
# Seven      - 97.4
# Eight      - 97.4
# Nine       - 97.2
#
#  | Global training round : 46/50 |
#
#
# Average test loss: 0.0514, Test accuracy: 9842/10000 (98.42%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 99.0
# Three      - 98.1
# Four       - 98.5
# Five       - 98.9
# Six        - 98.6
# Seven      - 97.5
# Eight      - 97.4
# Nine       - 97.2
#
#  | Global training round : 47/50 |
#
#
# Average test loss: 0.0507, Test accuracy: 9848/10000 (98.48%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 98.9
# Three      - 98.1
# Four       - 98.8
# Five       - 99.0
# Six        - 98.6
# Seven      - 97.5
# Eight      - 97.8
# Nine       - 97.1
#
#  | Global training round : 48/50 |
#
#
# Average test loss: 0.0508, Test accuracy: 9837/10000 (98.37%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.5
# Two        - 98.7
# Three      - 98.2
# Four       - 98.6
# Five       - 98.8
# Six        - 98.5
# Seven      - 97.5
# Eight      - 97.4
# Nine       - 97.1
#
#  | Global training round : 49/50 |
#
#
# Average test loss: 0.0502, Test accuracy: 9843/10000 (98.43%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.4
# Two        - 98.8
# Three      - 98.1
# Four       - 98.7
# Five       - 98.9
# Six        - 98.6
# Seven      - 97.4
# Eight      - 97.8
# Nine       - 97.1
#
#  | Global training round : 50/50 |
#
#
# Average test loss: 0.0500, Test accuracy: 9841/10000 (98.41%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.9
# Three      - 98.1
# Four       - 98.7
# Five       - 98.8
# Six        - 98.6
# Seven      - 97.4
# Eight      - 97.3
# Nine       - 97.2
# Last 10 updates results
#
# Average test loss: 0.0519, Test accuracy: 9835/10000 (98.35%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.7
# Three      - 98.1
# Four       - 98.5
# Five       - 98.8
# Six        - 98.5
# Seven      - 97.3
# Eight      - 97.3
# Nine       - 97.2
# Global accuracies:  [75.88, 89.92, 92.74, 93.95, 94.92, 95.56, 95.96, 96.14, 96.53, 96.71, 96.86, 96.99, 97.15, 97.24, 97.31, 97.41, 97.44, 97.6, 97.6, 97.64, 97.78, 97.75, 97.8, 97.75, 97.89, 97.94, 97.92, 98.03, 98.04, 98.04, 98.07, 98.11, 98.11, 98.13, 98.15, 98.15, 98.19, 98.22, 98.25, 98.25, 98.24, 98.25, 98.27, 98.34, 98.33, 98.42, 98.48, 98.37, 98.43, 98.41, 98.35]
# Class 7 accuracies:  [89.4, 90.76, 91.83, 92.8, 92.61, 93.48, 93.97, 94.16, 94.46, 94.55, 94.94, 95.43, 95.62, 95.72, 95.91, 95.82, 96.01, 96.4, 96.6, 96.4, 96.6, 96.4, 96.69, 96.69, 96.6, 96.69, 96.5, 96.79, 96.79, 96.79, 96.89, 96.79, 96.79, 97.18, 97.18, 97.18, 97.08, 97.37, 97.37, 97.18, 97.18, 97.08, 97.28, 97.37, 97.37, 97.47, 97.47, 97.47, 97.37, 97.37, 97.28]
# Test loss: [1.2199, 0.4018, 0.2704, 0.2105, 0.1753, 0.1537, 0.1384, 0.1269, 0.1186, 0.1105, 0.1042, 0.0999, 0.0947, 0.0917, 0.0875, 0.0856, 0.083, 0.0804, 0.0786, 0.0767, 0.0741, 0.0727, 0.0714, 0.0694, 0.0679, 0.0668, 0.0664, 0.0649, 0.0635, 0.0625, 0.0607, 0.0611, 0.06, 0.0592, 0.0571, 0.0573, 0.0564, 0.0559, 0.0552, 0.0551, 0.0548, 0.054, 0.0529, 0.0528, 0.0528, 0.0514, 0.0507, 0.0508, 0.0502, 0.05, 0.0519]
# Attack succes rate: 0.29
# Average CPU aggregation runtime: 0.005877232551574707
#
# --> End of Experiment.
#
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peets instances
# Data set: MNIST
# Data distribution: IID
# Aggregation rule: fedavg
# Attack Type: label_flipping
# Attackers Ratio: 10.0 %
# Malicious Behavior Rate: 100 %
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/50 [00:00<?, ?it/s]
#  | Global training round : 1/50 |
#
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
#
# Average test loss: 1.2683, Test accuracy: 7504/10000 (75.04%)
#
# Class      - Accuracy
# Zero       - 94.1
# One        - 98.2
# Two        - 74.4
# Three      - 85.5
# Four       - 84.8
# Five       - 46.7
# Six        - 79.4
# Seven      - 80.2
# Eight      - 53.6
# Nine       - 47.4
#
#  | Global training round : 2/50 |
#
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
#
# Average test loss: 0.4115, Test accuracy: 8936/10000 (89.36%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 97.3
# Two        - 91.1
# Three      - 88.3
# Four       - 95.4
# Five       - 85.7
# Six        - 94.7
# Seven      - 86.6
# Eight      - 81.6
# Nine       - 74.0
#
#  | Global training round : 3/50 |
#
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
#
# Average test loss: 0.2784, Test accuracy: 9244/10000 (92.44%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 98.4
# Two        - 92.6
# Three      - 91.8
# Four       - 96.3
# Five       - 91.6
# Six        - 95.5
# Seven      - 86.9
# Eight      - 85.9
# Nine       - 86.9
#
#  | Global training round : 4/50 |
#
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
#
# Average test loss: 0.2188, Test accuracy: 9386/10000 (93.86%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.7
# Two        - 93.3
# Three      - 93.6
# Four       - 96.4
# Five       - 93.7
# Six        - 96.6
# Seven      - 88.0
# Eight      - 89.0
# Nine       - 90.5
#
#  | Global training round : 5/50 |
#
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
#
# Average test loss: 0.1841, Test accuracy: 9454/10000 (94.54%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.6
# Two        - 94.2
# Three      - 93.9
# Four       - 96.6
# Five       - 95.9
# Six        - 96.9
# Seven      - 87.8
# Eight      - 91.0
# Nine       - 92.3
#
#  | Global training round : 6/50 |
#
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
#
# Average test loss: 0.1594, Test accuracy: 9531/10000 (95.31%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.9
# Two        - 95.7
# Three      - 95.2
# Four       - 96.4
# Five       - 96.1
# Six        - 97.0
# Seven      - 90.0
# Eight      - 91.0
# Nine       - 93.9
#
#  | Global training round : 7/50 |
#
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
#
# Average test loss: 0.1469, Test accuracy: 9559/10000 (95.59%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.9
# Two        - 96.3
# Three      - 95.0
# Four       - 97.1
# Five       - 96.7
# Six        - 97.4
# Seven      - 89.4
# Eight      - 92.1
# Nine       - 94.2
#
#  | Global training round : 8/50 |
#
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
#
# Average test loss: 0.1359, Test accuracy: 9590/10000 (95.90%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 96.5
# Three      - 96.0
# Four       - 97.4
# Five       - 97.4
# Six        - 97.6
# Seven      - 90.0
# Eight      - 92.2
# Nine       - 94.4
#
#  | Global training round : 9/50 |
#
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
#
# Average test loss: 0.1273, Test accuracy: 9626/10000 (96.26%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 96.9
# Three      - 96.6
# Four       - 97.4
# Five       - 98.0
# Six        - 97.6
# Seven      - 90.5
# Eight      - 93.1
# Nine       - 95.0
#
#  | Global training round : 10/50 |
#
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
#
# Average test loss: 0.1183, Test accuracy: 9645/10000 (96.45%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.1
# Two        - 96.9
# Three      - 96.8
# Four       - 97.3
# Five       - 98.2
# Six        - 97.7
# Seven      - 91.2
# Eight      - 93.6
# Nine       - 95.0
#
#  | Global training round : 11/50 |
#
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
#
# Average test loss: 0.1110, Test accuracy: 9662/10000 (96.62%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.0
# Two        - 97.4
# Three      - 96.4
# Four       - 97.1
# Five       - 98.2
# Six        - 97.6
# Seven      - 91.8
# Eight      - 94.4
# Nine       - 95.3
#
#  | Global training round : 12/50 |
#
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
#
# Average test loss: 0.1046, Test accuracy: 9682/10000 (96.82%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.9
# Two        - 97.5
# Three      - 96.6
# Four       - 97.3
# Five       - 98.4
# Six        - 97.6
# Seven      - 92.7
# Eight      - 94.8
# Nine       - 95.6
#
#  | Global training round : 13/50 |
#
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
#
# Average test loss: 0.1012, Test accuracy: 9701/10000 (97.01%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.2
# Two        - 97.6
# Three      - 97.1
# Four       - 97.6
# Five       - 98.4
# Six        - 98.0
# Seven      - 93.0
# Eight      - 94.4
# Nine       - 95.9
#
#  | Global training round : 14/50 |
#
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
#
# Average test loss: 0.0978, Test accuracy: 9709/10000 (97.09%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.2
# Two        - 97.4
# Three      - 97.2
# Four       - 97.6
# Five       - 98.7
# Six        - 97.9
# Seven      - 93.4
# Eight      - 94.7
# Nine       - 96.0
#
#  | Global training round : 15/50 |
#
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
#
# Average test loss: 0.0931, Test accuracy: 9721/10000 (97.21%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.2
# Two        - 97.6
# Three      - 97.1
# Four       - 97.7
# Five       - 98.5
# Six        - 97.9
# Seven      - 94.1
# Eight      - 95.2
# Nine       - 95.9
#
#  | Global training round : 16/50 |
#
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
#
# Average test loss: 0.0900, Test accuracy: 9736/10000 (97.36%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 97.7
# Three      - 97.4
# Four       - 97.6
# Five       - 98.8
# Six        - 98.0
# Seven      - 94.1
# Eight      - 95.8
# Nine       - 96.2
#
#  | Global training round : 17/50 |
#
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
#
# Average test loss: 0.0883, Test accuracy: 9733/10000 (97.33%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.0
# Two        - 97.9
# Three      - 97.5
# Four       - 97.6
# Five       - 98.8
# Six        - 98.0
# Seven      - 93.5
# Eight      - 96.0
# Nine       - 96.1
#
#  | Global training round : 18/50 |
#
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
#
# Average test loss: 0.0845, Test accuracy: 9743/10000 (97.43%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 97.9
# Three      - 97.2
# Four       - 97.6
# Five       - 98.8
# Six        - 98.1
# Seven      - 94.0
# Eight      - 96.3
# Nine       - 96.4
#
#  | Global training round : 19/50 |
#
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
#
# Average test loss: 0.0829, Test accuracy: 9754/10000 (97.54%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.3
# Two        - 98.0
# Three      - 97.2
# Four       - 97.9
# Five       - 98.8
# Six        - 98.1
# Seven      - 94.3
# Eight      - 96.6
# Nine       - 96.4
#
#  | Global training round : 20/50 |
#
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
#
# Average test loss: 0.0808, Test accuracy: 9754/10000 (97.54%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.3
# Two        - 98.2
# Three      - 97.4
# Four       - 97.8
# Five       - 98.9
# Six        - 98.0
# Seven      - 94.3
# Eight      - 96.2
# Nine       - 96.4
#
#  | Global training round : 21/50 |
#
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
#
# Average test loss: 0.0783, Test accuracy: 9761/10000 (97.61%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.2
# Two        - 98.2
# Three      - 97.4
# Four       - 97.8
# Five       - 98.9
# Six        - 98.1
# Seven      - 94.8
# Eight      - 96.3
# Nine       - 96.4
#
#  | Global training round : 22/50 |
#
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
#
# Average test loss: 0.0776, Test accuracy: 9761/10000 (97.61%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.2
# Two        - 98.3
# Three      - 97.3
# Four       - 97.9
# Five       - 98.9
# Six        - 98.0
# Seven      - 94.3
# Eight      - 96.9
# Nine       - 96.4
#
#  | Global training round : 23/50 |
#
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
#
# Average test loss: 0.0751, Test accuracy: 9768/10000 (97.68%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 98.4
# Three      - 97.5
# Four       - 97.8
# Five       - 98.9
# Six        - 98.0
# Seven      - 94.8
# Eight      - 96.6
# Nine       - 96.3
#
#  | Global training round : 24/50 |
#
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
#
# Average test loss: 0.0742, Test accuracy: 9774/10000 (97.74%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.2
# Two        - 98.4
# Three      - 97.6
# Four       - 98.3
# Five       - 98.9
# Six        - 98.2
# Seven      - 94.6
# Eight      - 96.8
# Nine       - 96.4
#
#  | Global training round : 25/50 |
#
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
#
# Average test loss: 0.0723, Test accuracy: 9775/10000 (97.75%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.2
# Two        - 98.4
# Three      - 97.5
# Four       - 98.2
# Five       - 98.9
# Six        - 98.2
# Seven      - 94.9
# Eight      - 96.9
# Nine       - 96.3
#
#  | Global training round : 26/50 |
#
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
#
# Average test loss: 0.0711, Test accuracy: 9777/10000 (97.77%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.2
# Two        - 98.4
# Three      - 97.5
# Four       - 98.3
# Five       - 98.9
# Six        - 98.1
# Seven      - 95.0
# Eight      - 96.8
# Nine       - 96.4
#
#  | Global training round : 27/50 |
#
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
#
# Average test loss: 0.0702, Test accuracy: 9786/10000 (97.86%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.4
# Two        - 98.7
# Three      - 97.6
# Four       - 98.2
# Five       - 98.9
# Six        - 98.1
# Seven      - 95.3
# Eight      - 96.5
# Nine       - 96.7
#
#  | Global training round : 28/50 |
#
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
#
# Average test loss: 0.0685, Test accuracy: 9788/10000 (97.88%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.1
# Two        - 98.6
# Three      - 97.6
# Four       - 98.5
# Five       - 98.9
# Six        - 98.1
# Seven      - 95.3
# Eight      - 96.9
# Nine       - 96.5
#
#  | Global training round : 29/50 |
#
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
#
# Average test loss: 0.0671, Test accuracy: 9794/10000 (97.94%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.1
# Two        - 98.7
# Three      - 97.8
# Four       - 98.3
# Five       - 98.9
# Six        - 98.1
# Seven      - 95.1
# Eight      - 97.1
# Nine       - 97.0
#
#  | Global training round : 30/50 |
#
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
#
# Average test loss: 0.0653, Test accuracy: 9798/10000 (97.98%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.1
# Two        - 98.6
# Three      - 97.8
# Four       - 98.1
# Five       - 98.9
# Six        - 98.1
# Seven      - 95.6
# Eight      - 97.1
# Nine       - 97.0
#
#  | Global training round : 31/50 |
#
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
#
# Average test loss: 0.0652, Test accuracy: 9797/10000 (97.97%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.3
# Two        - 98.6
# Three      - 97.8
# Four       - 98.5
# Five       - 98.9
# Six        - 98.1
# Seven      - 95.3
# Eight      - 97.1
# Nine       - 96.8
#
#  | Global training round : 32/50 |
#
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
#
# Average test loss: 0.0643, Test accuracy: 9801/10000 (98.01%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.3
# Two        - 98.8
# Three      - 97.8
# Four       - 98.3
# Five       - 98.9
# Six        - 98.1
# Seven      - 95.5
# Eight      - 96.8
# Nine       - 97.2
#
#  | Global training round : 33/50 |
#
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
#
# Average test loss: 0.0635, Test accuracy: 9805/10000 (98.05%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.3
# Two        - 98.8
# Three      - 97.8
# Four       - 98.2
# Five       - 98.9
# Six        - 98.2
# Seven      - 95.5
# Eight      - 97.2
# Nine       - 97.1
#
#  | Global training round : 34/50 |
#
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
#
# Average test loss: 0.0630, Test accuracy: 9806/10000 (98.06%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.1
# Two        - 99.0
# Three      - 97.9
# Four       - 98.3
# Five       - 99.0
# Six        - 98.2
# Seven      - 95.3
# Eight      - 97.3
# Nine       - 97.1
#
#  | Global training round : 35/50 |
#
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
#
# Average test loss: 0.0614, Test accuracy: 9810/10000 (98.10%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.4
# Two        - 98.7
# Three      - 97.9
# Four       - 98.4
# Five       - 99.0
# Six        - 98.1
# Seven      - 95.7
# Eight      - 97.1
# Nine       - 97.2
#
#  | Global training round : 36/50 |
#
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
#
# Average test loss: 0.0608, Test accuracy: 9808/10000 (98.08%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.4
# Two        - 98.6
# Three      - 97.9
# Four       - 98.3
# Five       - 98.8
# Six        - 98.2
# Seven      - 96.0
# Eight      - 97.0
# Nine       - 97.1
#
#  | Global training round : 37/50 |
#
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
#
# Average test loss: 0.0602, Test accuracy: 9811/10000 (98.11%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.6
# Two        - 98.7
# Three      - 97.9
# Four       - 98.5
# Five       - 98.8
# Six        - 98.2
# Seven      - 95.9
# Eight      - 97.1
# Nine       - 96.9
#
#  | Global training round : 38/50 |
#
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
#
# Average test loss: 0.0585, Test accuracy: 9817/10000 (98.17%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.4
# Two        - 98.8
# Three      - 97.9
# Four       - 98.3
# Five       - 98.8
# Six        - 98.3
# Seven      - 96.3
# Eight      - 97.4
# Nine       - 97.0
#
#  | Global training round : 39/50 |
#
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
#
# Average test loss: 0.0584, Test accuracy: 9817/10000 (98.17%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.4
# Two        - 98.9
# Three      - 97.9
# Four       - 98.2
# Five       - 98.8
# Six        - 98.3
# Seven      - 96.5
# Eight      - 97.2
# Nine       - 97.0
#
#  | Global training round : 40/50 |
#
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
#
# Average test loss: 0.0584, Test accuracy: 9822/10000 (98.22%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.4
# Two        - 98.9
# Three      - 98.2
# Four       - 98.3
# Five       - 98.9
# Six        - 98.3
# Seven      - 95.9
# Eight      - 97.6
# Nine       - 97.2
#
#  | Global training round : 41/50 |
#
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
#
# Average test loss: 0.0570, Test accuracy: 9824/10000 (98.24%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.4
# Two        - 98.7
# Three      - 98.3
# Four       - 98.1
# Five       - 99.0
# Six        - 98.3
# Seven      - 96.3
# Eight      - 97.5
# Nine       - 97.3
#
#  | Global training round : 42/50 |
#
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
#
# Average test loss: 0.0564, Test accuracy: 9828/10000 (98.28%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.4
# Two        - 99.0
# Three      - 98.0
# Four       - 98.3
# Five       - 99.0
# Six        - 98.4
# Seven      - 96.5
# Eight      - 97.8
# Nine       - 96.9
#
#  | Global training round : 43/50 |
#
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
#
# Average test loss: 0.0559, Test accuracy: 9824/10000 (98.24%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.8
# Three      - 98.0
# Four       - 98.4
# Five       - 98.9
# Six        - 98.4
# Seven      - 96.5
# Eight      - 97.2
# Nine       - 97.1
#
#  | Global training round : 44/50 |
#
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
#
# Average test loss: 0.0561, Test accuracy: 9826/10000 (98.26%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.5
# Two        - 99.0
# Three      - 98.1
# Four       - 98.4
# Five       - 99.0
# Six        - 98.4
# Seven      - 96.4
# Eight      - 97.3
# Nine       - 97.0
#
#  | Global training round : 45/50 |
#
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
#
# Average test loss: 0.0553, Test accuracy: 9831/10000 (98.31%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 99.0
# Three      - 98.4
# Four       - 98.5
# Five       - 99.0
# Six        - 98.4
# Seven      - 96.1
# Eight      - 97.5
# Nine       - 97.1
#
#  | Global training round : 46/50 |
#
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
#
# Average test loss: 0.0547, Test accuracy: 9837/10000 (98.37%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 98.9
# Three      - 98.4
# Four       - 98.5
# Five       - 99.0
# Six        - 98.4
# Seven      - 96.4
# Eight      - 97.8
# Nine       - 97.2
#
#  | Global training round : 47/50 |
#
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
#
# Average test loss: 0.0548, Test accuracy: 9835/10000 (98.35%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 99.0
# Three      - 98.4
# Four       - 98.5
# Five       - 98.8
# Six        - 98.6
# Seven      - 96.4
# Eight      - 97.5
# Nine       - 97.2
#
#  | Global training round : 48/50 |
#
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
#
# Average test loss: 0.0543, Test accuracy: 9839/10000 (98.39%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 99.1
# Three      - 98.4
# Four       - 98.5
# Five       - 98.9
# Six        - 98.6
# Seven      - 96.4
# Eight      - 97.6
# Nine       - 97.3
#
#  | Global training round : 49/50 |
#
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
#
# Average test loss: 0.0545, Test accuracy: 9835/10000 (98.35%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.6
# Two        - 99.0
# Three      - 98.3
# Four       - 98.6
# Five       - 98.8
# Six        - 98.6
# Seven      - 96.4
# Eight      - 97.4
# Nine       - 97.2
#
#  | Global training round : 50/50 |
#
# Label flipping attack launched by Peer 40 to flip class  7  to class  1
# Label flipping attack launched by Peer 6 to flip class  7  to class  1
# Label flipping attack launched by Peer 8 to flip class  7  to class  1
# Label flipping attack launched by Peer 12 to flip class  7  to class  1
# Label flipping attack launched by Peer 9 to flip class  7  to class  1
#
# Average test loss: 0.0532, Test accuracy: 9840/10000 (98.40%)
#
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 99.0
# Three      - 98.3
# Four       - 98.6
# Five       - 98.8
# Six        - 98.6
# Seven      - 96.7
# Eight      - 97.7
# Nine       - 97.2
# Last 10 updates results
#
# Average test loss: 0.0550, Test accuracy: 9834/10000 (98.34%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 99.5
# One        - 99.5
# Two        - 99.0
# Three      - 98.3
# Four       - 98.4
# Five       - 98.9
# Six        - 98.5
# Seven      - 96.4
# Eight      - 97.6
# Nine       - 97.2
# Global accuracies:  [75.04, 89.36, 92.44, 93.86, 94.54, 95.31, 95.59, 95.9, 96.26, 96.45, 96.62, 96.82, 97.01, 97.09, 97.21, 97.36, 97.33, 97.43, 97.54, 97.54, 97.61, 97.61, 97.68, 97.74, 97.75, 97.77, 97.86, 97.88, 97.94, 97.98, 97.97, 98.01, 98.05, 98.06, 98.1, 98.08, 98.11, 98.17, 98.17, 98.22, 98.24, 98.28, 98.24, 98.26, 98.31, 98.37, 98.35, 98.39, 98.35, 98.4, 98.34]
# Class 7 accuracies:  [80.16, 86.58, 86.87, 88.04, 87.84, 89.98, 89.4, 89.98, 90.47, 91.25, 91.83, 92.7, 93.0, 93.39, 94.07, 94.07, 93.48, 93.97, 94.26, 94.26, 94.84, 94.26, 94.84, 94.65, 94.94, 95.04, 95.33, 95.33, 95.14, 95.62, 95.33, 95.53, 95.53, 95.33, 95.72, 96.01, 95.91, 96.3, 96.5, 95.91, 96.3, 96.5, 96.5, 96.4, 96.11, 96.4, 96.4, 96.4, 96.4, 96.69, 96.4]
# Test loss: [1.2683, 0.4115, 0.2784, 0.2188, 0.1841, 0.1594, 0.1469, 0.1359, 0.1273, 0.1183, 0.111, 0.1046, 0.1012, 0.0978, 0.0931, 0.09, 0.0883, 0.0845, 0.0829, 0.0808, 0.0783, 0.0776, 0.0751, 0.0742, 0.0723, 0.0711, 0.0702, 0.0685, 0.0671, 0.0653, 0.0652, 0.0643, 0.0635, 0.063, 0.0614, 0.0608, 0.0602, 0.0585, 0.0584, 0.0584, 0.057, 0.0564, 0.0559, 0.0561, 0.0553, 0.0547, 0.0548, 0.0543, 0.0545, 0.0532, 0.055]
# Attack succes rate: 0.39
# Average CPU aggregation runtime: 0.005953540802001953
#
# --> End of Experiment.

# %%
RULE = 'median'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.4]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, resume = False)

# %%
RULE = 'tmean'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.4]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, resume = False)

# %%
RULE = 'mkrum'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.4]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, resume = False)

# %%
RULE = 'foolsgold'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.4]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, resume = False)

# %%
RULE = 'Tolpegin'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.4]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, resume = False)

# %%
RULE = 'FLAME'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.4]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, resume = False)

# %%
RULE = 'lfighter'
ATTACK_TYPE='label_flipping'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.4]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, resume = False)
